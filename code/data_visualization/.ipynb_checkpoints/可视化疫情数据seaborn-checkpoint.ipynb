# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
import requests
import time
import numpy as np

# %%
result = requests.get('https://lab.isaaclin.cn/nCoV/api/area')
data = result.json()
df = pd.DataFrame.from_records(data['results'])
df.head(10)
# Out:
#    locationId continentName continentEnglishName countryName  \
# 0      961006            欧洲               Europe          荷兰
# 1      964006            欧洲               Europe         俄罗斯
# 2      985004            非洲               Africa       埃塞俄比亚
# 3      963003            欧洲               Europe          德国
# 4      973002           南美洲        South America        玻利维亚
# 5      953004            亚洲                 Asia        马尔代夫
# 6      985006            非洲               Africa         卢旺达
# 7      954005            亚洲                 Asia      乌兹别克斯坦
# 8      965013            欧洲               Europe        塞尔维亚
# 9      954001            亚洲                 Asia       哈萨克斯坦
#
#    countryEnglishName                   countryFullName provinceName  \
# 0         Netherlands                       Netherlands           荷兰
# 1              Russia                Russian Federation          俄罗斯
# 2            Ethiopia                          Ethiopia        埃塞俄比亚
# 3             Germany                           Germany           德国
# 4             Bolivia  Bolivia (Plurinational State of)         玻利维亚
# 5            Maldives                          Maldives         马尔代夫
# 6  Republic of Rwanda                            Rwanda          卢旺达
# 7          Uzbekistan                         Uzbekstan       乌兹别克斯坦
# 8  Republic of Serbia                            Serbia         塞尔维亚
# 9          Kazakhstan                        Kazakhstan        哈萨克斯坦
#
#   provinceEnglishName provinceShortName  currentConfirmedCount  \
# 0         Netherlands                荷兰                  29779
# 1              Russia               俄罗斯                 236696
# 2            Ethiopia             埃塞俄比亚                   1768
# 3             Germany                德国                   5542
# 4             Bolivia              玻利维亚                  12745
# 5            Maldives              马尔代夫                   1178
# 6  Republic of Rwanda               卢旺达                    152
# 7          Uzbekistan            乌兹别克斯坦                   1699
# 8  Republic of Serbia              塞尔维亚                    922
# 9          Kazakhstan             哈萨克斯坦                   6975
#
#    confirmedCount  suspectedCount  curedCount  deadCount comment cities  \
# 0           47574               0       11782       6013           None
# 1          485235               0      242397       6142           None
# 2            2156               0         361         27           None
# 3          184453               0      170200       8711           None
# 4           13358               0         159        454           None
# 5            1903               0         717          8           None
# 6             451               0         297          2           None
# 7            4352               0        2636         17           None
# 8           13130               0       11927        281           None
# 9           14770               0        7737         58           None
#
#       updateTime
# 0  1591688926795
# 1  1591688926795
# 2  1591688926795
# 3  1591688926795
# 4  1591688620807
# 5  1591688620807
# 6  1591688620807
# 7  1591688620807
# 8  1591688620807
# 9  1591688620807

# %%
df['updateTime'] = pd.to_datetime(df['updateTime'].values, unit='ms')
df['updateTime'] = df['updateTime'].apply(lambda x:x.strftime('%Y-%m'))
df
# Out:
#      locationId continentName continentEnglishName    countryName  \
# 0        961006            欧洲               Europe             荷兰
# 1        964006            欧洲               Europe            俄罗斯
# 2        985004            非洲               Africa          埃塞俄比亚
# 3        963003            欧洲               Europe             德国
# 4        973002           南美洲        South America           玻利维亚
# ..          ...           ...                  ...            ...
# 252           0            欧洲               Europe  大不列颠及北爱尔兰联合王国
# 253           0            欧洲               Europe      英国（含北爱尔兰）
# 254           0            欧洲               Europe           北爱尔兰
# 255      630000            亚洲                 Asia             中国
# 256      540000            亚洲                 Asia             中国
#
#                               countryEnglishName  \
# 0                                    Netherlands
# 1                                         Russia
# 2                                       Ethiopia
# 3                                        Germany
# 4                                        Bolivia
# ..                                           ...
# 252  United Kingdom of Great Britain and Ireland
# 253                               United Kingdom
# 254                             Northern Ireland
# 255                                        China
# 256                                        China
#
#                       countryFullName   provinceName  \
# 0                         Netherlands             荷兰
# 1                  Russian Federation            俄罗斯
# 2                            Ethiopia          埃塞俄比亚
# 3                             Germany             德国
# 4    Bolivia (Plurinational State of)           玻利维亚
# ..                                ...            ...
# 252                              None  大不列颠及北爱尔兰联合王国
# 253                              None      英国（含北爱尔兰）
# 254                              None           北爱尔兰
# 255                              None            青海省
# 256                              None          西藏自治区
#
#                              provinceEnglishName provinceShortName  \
# 0                                    Netherlands                荷兰
# 1                                         Russia               俄罗斯
# 2                                       Ethiopia             埃塞俄比亚
# 3                                        Germany                德国
# 4                                        Bolivia              玻利维亚
# ..                                           ...               ...
# 252  United Kingdom of Great Britain and Ireland     大不列颠及北爱尔兰联合王国
# 253                               United Kingdom         英国（含北爱尔兰）
# 254                             Northern Ireland              北爱尔兰
# 255                                      Qinghai                青海
# 256                                       Xizang                西藏
#
#      currentConfirmedCount  confirmedCount  suspectedCount  curedCount  \
# 0                    29779           47574               0       11782
# 1                   236696          485235               0      242397
# 2                     1768            2156               0         361
# 3                     5542          184453               0      170200
# 4                    12745           13358               0         159
# ..                     ...             ...             ...         ...
# 252                     12              20               0           8
# 253                     12              20               0           8
# 254                      1               1               0           0
# 255                      0              18               0          18
# 256                      0               1               0           1
#
#      deadCount comment                                             cities  \
# 0         6013                                                       None
# 1         6142                                                       None
# 2           27                                                       None
# 3         8711                                                       None
# 4          454                                                       None
# ..         ...     ...                                                ...
# 252          0                                                       None
# 253          0                                                       None
# 254          0                                                       None
# 255          0          [{'cityName': '西宁', 'currentConfirmedCount': 0...
# 256          0          [{'cityName': '拉萨', 'currentConfirmedCount': 0...
#
#     updateTime
# 0      2020-06
# 1      2020-06
# 2      2020-06
# 3      2020-06
# 4      2020-06
# ..         ...
# 252    2020-02
# 253    2020-02
# 254    2020-02
# 255    2020-02
# 256    2020-02
#
# [257 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   locationId             257 non-null    int64
#  1   continentName          257 non-null    object
#  2   continentEnglishName   257 non-null    object
#  3   countryName            257 non-null    object
#  4   countryEnglishName     223 non-null    object
#  5   countryFullName        219 non-null    object
#  6   provinceName           257 non-null    object
#  7   provinceEnglishName    223 non-null    object
#  8   provinceShortName      257 non-null    object
#  9   currentConfirmedCount  257 non-null    int64
#  10  confirmedCount         257 non-null    int64
#  11  suspectedCount         257 non-null    int64
#  12  curedCount             257 non-null    int64
#  13  deadCount              257 non-null    int64
#  14  comment                256 non-null    object
#  15  cities                 34 non-null     object
#  16  updateTime             257 non-null    object
# dtypes: int64(6), object(11)
# memory usage: 34.3+ KB

# %%
df1 = df.drop_duplicates(subset=['updateTime', 'countryName'], keep='last')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 0 to 256
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   locationId             227 non-null    int64
#  1   continentName          227 non-null    object
#  2   continentEnglishName   227 non-null    object
#  3   countryName            227 non-null    object
#  4   countryEnglishName     193 non-null    object
#  5   countryFullName        218 non-null    object
#  6   provinceName           227 non-null    object
#  7   provinceEnglishName    193 non-null    object
#  8   provinceShortName      227 non-null    object
#  9   currentConfirmedCount  227 non-null    int64
#  10  confirmedCount         227 non-null    int64
#  11  suspectedCount         227 non-null    int64
#  12  curedCount             227 non-null    int64
#  13  deadCount              227 non-null    int64
#  14  comment                227 non-null    object
#  15  cities                 5 non-null      object
#  16  updateTime             227 non-null    object
# dtypes: int64(6), object(11)
# memory usage: 31.9+ KB

# %%
df2 = df1.groupby(['continentName']).sum()
df2
# Out:
#                locationId  currentConfirmedCount  confirmedCount  \
# continentName
# 亚洲               44160305                 523586         1316795
# 其他                      0                    146             733
# 北美洲              20431108                1426231         2241009
# 南美洲              10703066                 643634         1157252
# 大洋洲               3960019                    568            8752
# 欧洲               41429266                 834886         2068741
# 非洲               47184328                 112116          198200
#
#                suspectedCount  curedCount  deadCount
# continentName
# 亚洲                        397      762116      31093
# 其他                          0         574         13
# 北美洲                         0      680336     134442
# 南美洲                         0      463084      50534
# 大洋洲                         4        8053        131
# 欧洲                          0     1054669     179186
# 非洲                          0       80701       5383

# %%
df3 = df2.drop('locationId', axis=1).reset_index()

# %%
df3
# Out:
#   continentName  currentConfirmedCount  confirmedCount  suspectedCount  \
# 0            亚洲                 523586         1316795             397
# 1            其他                    146             733               0
# 2           北美洲                1426231         2241009               0
# 3           南美洲                 643634         1157252               0
# 4           大洋洲                    568            8752               4
# 5            欧洲                 834886         2068741               0
# 6            非洲                 112116          198200               0
#
#    curedCount  deadCount
# 0      762116      31093
# 1         574         13
# 2      680336     134442
# 3      463084      50534
# 4        8053        131
# 5     1054669     179186
# 6       80701       5383

# %%
plt.rcParams["font.family"]="AR PL UKai CN" # 根据系统的字体来显示避免乱码
sns.catplot(x="continentName", y="confirmedCount", kind="bar", data=df3).set(title = '各洲确诊数量')

# %%
sns.catplot(x="continentName", y="curedCount", kind="bar", data=df3).set(title = '各洲治愈数量')

# %%
sns.catplot(x="continentName", y="deadCount", kind="bar", data=df3).set(title = '各洲死亡数量')

# %%
df3.plot(x="continentName", kind="bar")

# %%
df1
# Out:
#      locationId continentName continentEnglishName    countryName  \
# 0        961006            欧洲               Europe             荷兰
# 1        964006            欧洲               Europe            俄罗斯
# 2        985004            非洲               Africa          埃塞俄比亚
# 3        963003            欧洲               Europe             德国
# 4        973002           南美洲        South America           玻利维亚
# ..          ...           ...                  ...            ...
# 251      650000            亚洲                 Asia             中国
# 252           0            欧洲               Europe  大不列颠及北爱尔兰联合王国
# 253           0            欧洲               Europe      英国（含北爱尔兰）
# 254           0            欧洲               Europe           北爱尔兰
# 256      540000            亚洲                 Asia             中国
#
#                               countryEnglishName  \
# 0                                    Netherlands
# 1                                         Russia
# 2                                       Ethiopia
# 3                                        Germany
# 4                                        Bolivia
# ..                                           ...
# 251                                        China
# 252  United Kingdom of Great Britain and Ireland
# 253                               United Kingdom
# 254                             Northern Ireland
# 256                                        China
#
#                       countryFullName   provinceName  \
# 0                         Netherlands             荷兰
# 1                  Russian Federation            俄罗斯
# 2                            Ethiopia          埃塞俄比亚
# 3                             Germany             德国
# 4    Bolivia (Plurinational State of)           玻利维亚
# ..                                ...            ...
# 251                              None       新疆维吾尔自治区
# 252                              None  大不列颠及北爱尔兰联合王国
# 253                              None      英国（含北爱尔兰）
# 254                              None           北爱尔兰
# 256                              None          西藏自治区
#
#                              provinceEnglishName provinceShortName  \
# 0                                    Netherlands                荷兰
# 1                                         Russia               俄罗斯
# 2                                       Ethiopia             埃塞俄比亚
# 3                                        Germany                德国
# 4                                        Bolivia              玻利维亚
# ..                                           ...               ...
# 251                                     Xinjiang                新疆
# 252  United Kingdom of Great Britain and Ireland     大不列颠及北爱尔兰联合王国
# 253                               United Kingdom         英国（含北爱尔兰）
# 254                             Northern Ireland              北爱尔兰
# 256                                       Xizang                西藏
#
#      currentConfirmedCount  confirmedCount  suspectedCount  curedCount  \
# 0                    29779           47574               0       11782
# 1                   236696          485235               0      242397
# 2                     1768            2156               0         361
# 3                     5542          184453               0      170200
# 4                    12745           13358               0         159
# ..                     ...             ...             ...         ...
# 251                      0              76               0          73
# 252                     12              20               0           8
# 253                     12              20               0           8
# 254                      1               1               0           0
# 256                      0               1               0           1
#
#      deadCount comment                                             cities  \
# 0         6013                                                       None
# 1         6142                                                       None
# 2           27                                                       None
# 3         8711                                                       None
# 4          454                                                       None
# ..         ...     ...                                                ...
# 251          3          [{'cityName': '乌鲁木齐', 'currentConfirmedCount':...
# 252          0                                                       None
# 253          0                                                       None
# 254          0                                                       None
# 256          0          [{'cityName': '拉萨', 'currentConfirmedCount': 0...
#
#     updateTime
# 0      2020-06
# 1      2020-06
# 2      2020-06
# 3      2020-06
# 4      2020-06
# ..         ...
# 251    2020-03
# 252    2020-02
# 253    2020-02
# 254    2020-02
# 256    2020-02
#
# [227 rows x 17 columns]

# %%
df_country = df1.loc[df1['countryName'] == df1['provinceShortName']].reset_index()
df_country = pd.DataFrame(df_country, columns=['countryName', 'confirmedCount', 'updateTime'])
df_country.sort_values(by='confirmedCount')
df_country.tail(20)
# Out:
#   File "<ipython-input-55-177e0dcca080>", line 1
#     df_country = df1.loc[(df1['countryName'] == df1['provinceShortName']) && df1['updateTime']=='2020-06'].reset_index()
#                                                                            ^
# SyntaxError: invalid syntax

# %%
sns.lineplot(x='updateTime', y='confirmedCount', hue='countryName', data=df_country)
