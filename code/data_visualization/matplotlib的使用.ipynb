# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 折线图

# %%
a = np.random.rand(100)
s = pd.Series(a)
s
# Out:
# 0     0.812566
# 1     0.185927
# 2     0.328187
# 3     0.635439
# 4     0.173827
#         ...
# 95    0.324694
# 96    0.798185
# 97    0.254028
# 98    0.939132
# 99    0.771965
# Length: 100, dtype: float64

# %%
plt.plot(s)

# %%
plt.plot([1, 2, 6, 8, 9, 20], 'x')
plt.xlabel('lol')
plt.ylabel('fxxkpython')
# Out:
# Text(0, 0.5, 'fxxkpython')

# %% [markdown]
# # 直方图

# %%
plt.hist(s)
# Out:
# (array([ 7.,  8.,  8.,  4.,  9., 13., 15.,  9., 17., 10.]),
#  array([0.00148198, 0.09959078, 0.19769958, 0.29580838, 0.39391717,
#         0.49202597, 0.59013477, 0.68824356, 0.78635236, 0.88446116,
#         0.98256996]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # 条形图

# %%
l1 = ['python', 'c', 'java', 'js', 'go']
l2 = [100, 60, 90, 70, 80]
plt.bar(l1, l2)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # 饼图

# %%
labels = ['java', 'python', 'go', 'c', 'js']
nums = [35, 66, 43, 22, 11]
plt.pie(labels=labels, x=nums)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f716b4e6790>,
#   <matplotlib.patches.Wedge at 0x7f716b51a450>,
#   <matplotlib.patches.Wedge at 0x7f716b51a7d0>,
#   <matplotlib.patches.Wedge at 0x7f716b451910>,
#   <matplotlib.patches.Wedge at 0x7f716b451ad0>],
#  [Text(0.8944866106002058, 0.6402294147076937, 'java'),
#   Text(-0.8213669061778613, 0.7316805350942502, 'python'),
#   Text(-0.39146933376684795, -1.027984319296817, 'go'),
#   Text(0.7812611090849362, -0.7743584954214524, 'c'),
#   Text(1.0791011800068298, -0.21340253819453045, 'js')])

# %% [markdown]
# # 散点图

# %%
x = np.random.rand(300)
y = np.random.rand(300)
plt.scatter(x, y)

# %% [markdown]
# # 箱图

# %%
a2 =np.random.randint(20, size=(10,4))
a2
# Out:
# array([[ 1,  8, 18, 11],
#        [12, 17,  6,  2],
#        [10,  2, 16,  9],
#        [ 8, 10,  5,  7],
#        [ 5,  7, 14,  6],
#        [ 4, 12,  0, 11],
#        [11, 19,  5,  5],
#        [10,  6, 15,  8],
#        [ 2,  4, 18, 18],
#        [ 2, 18,  1, 12]])

# %%
plt.boxplot(a2)
plt.show()
