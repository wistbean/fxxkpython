# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd

# %% [markdown]
# # 散点图

# %%
import plotly.express as px
x = np.random.rand(100)
y = np.random.rand(100)
fig = px.scatter(x=x, y=y)
fig.show()
# Out:
# <div>
#
#
#             <div id="663e7c94-fb68-4ab6-b0f6-5eee65c0fca1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("663e7c94-fb68-4ab6-b0f6-5eee65c0fca1")) {
#                     Plotly.newPlot(
#                         '663e7c94-fb68-4ab6-b0f6-5eee65c0fca1',
# ...

# %% [markdown]
# # 折线图

# %%
a = np.linspace(0, 1, 100)
b = np.random.randn(100)
fig = px.line(s, x=a, y=b, title='折线图演示')
fig.show()
# Out:
# <div>
#
#
#             <div id="5f999877-6295-4e1d-a907-dd110ff21c92" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f999877-6295-4e1d-a907-dd110ff21c92")) {
#                     Plotly.newPlot(
#                         '5f999877-6295-4e1d-a907-dd110ff21c92',
# ...

# %% [markdown]
# # 直方图

# %%
data = np.random.randint(20, size=(10, 4))
df = pd.DataFrame(data, columns=['one','two','three','four'])
fig = px.bar(df, x='one', y='two',
             hover_data=['three', 'four'], color='one', height=500)
fig.show()
# Out:
# <div>
#
#
#             <div id="fac19dc3-78c7-47b1-bfee-e6b920e77c02" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fac19dc3-78c7-47b1-bfee-e6b920e77c02")) {
#                     Plotly.newPlot(
#                         'fac19dc3-78c7-47b1-bfee-e6b920e77c02',
# ...

# %%
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.show()
# Out:
# <div>
#
#
#             <div id="2e2243e4-99b2-41c2-9d5d-7e46ecba51cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e2243e4-99b2-41c2-9d5d-7e46ecba51cc")) {
#                     Plotly.newPlot(
#                         '2e2243e4-99b2-41c2-9d5d-7e46ecba51cc',
#                         [{"type": "bar", "y": [2, 3, 1]}],
# ...

# %% [markdown]
# # 饼图

# %%
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.show()
# Out:
# <div>
#
#
#             <div id="84baeff7-5aaf-4d66-97c3-a27693b7fa39" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("84baeff7-5aaf-4d66-97c3-a27693b7fa39")) {
#                     Plotly.newPlot(
#                         '84baeff7-5aaf-4d66-97c3-a27693b7fa39',
# ...

# %%
labels = ['java', 'python', 'go', 'c', 'js']
nums = [35, 66, 43, 22, 11]
fig = go.Figure(data=[go.Pie(labels=labels, values=nums)])
fig.show()
# Out:
# <div>
#
#
#             <div id="f2c90014-b9d9-4d09-9080-db6b71eade67" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2c90014-b9d9-4d09-9080-db6b71eade67")) {
#                     Plotly.newPlot(
#                         'f2c90014-b9d9-4d09-9080-db6b71eade67',
#                         [{"labels": ["java", "python", "go", "c", "js"], "type": "pie", "values": [35, 66, 43, 22, 11]}],
# ...

# %% [markdown]
# # 箱线图

# %%
fig = px.box(df, x="day", y="total_bill")
fig.show()
# Out:
# <div>
#
#
#             <div id="9434c259-b18b-46ac-9cd9-c86024513233" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9434c259-b18b-46ac-9cd9-c86024513233")) {
#                     Plotly.newPlot(
#                         '9434c259-b18b-46ac-9cd9-c86024513233',
# ...
